# %% [markdown]
# # Classification
# ## Using SMOTE

# %%
import numpy as np
import pandas as pd
import json 
import imblearn

# %%
from sklearn.manifold import Isomap, TSNE, MDS, LocallyLinearEmbedding
from sklearn.preprocessing import LabelEncoder
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans

from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import AdaBoostClassifier

# %%
from missingpy import MissForest
# Out:
# /home/pedro/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df = pd.read_json('features_label.json')
df.head(3)
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.098792  0.246780  0.372182 -0.267302 -0.093455  0.154483 -0.149150
# 1 -0.073662  0.345128  0.301814 -0.476560  0.025313  0.079780 -0.086261
# 2 -0.239538  0.217312  0.391495 -0.259332 -0.096260  0.049797 -0.015582
#
#           7         8         9  ...       110       111       112       113  \
# 0  0.133048 -0.161907 -0.061863  ...  0.000803  0.799012  0.216770  0.488889
# 1  0.161001 -0.147534  0.065079  ...  0.001706  0.643200  0.207359  0.480000
# 2  0.133139 -0.179384 -0.108626  ... -0.001383  0.581315  0.272105  0.470588
#
#         114  115       116       117       118  class
# 0  0.288604    2  0.977778  3.893833  0.022222   None
# 1  0.288444    1  1.000000  3.384134  0.000000   None
# 2  0.288175    3  0.882353  3.008596  0.117647   None
#
# [3 rows x 120 columns]

# %%
df['class'] = df['class'].astype('category')
df.groupby('class').size()
# Out:
# class
# Q1      59
# Q2    9974
# Q4    9885
# dtype: int64

# %%
from sklearn import preprocessing
categorical = ['class']
le = preprocessing.LabelEncoder()
df[categorical] = df[categorical].apply(lambda series: pd.Series(
    le.fit_transform(series[series.notnull()]),
    index=series[series.notnull()].index
))

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
X, y = oversample.fit_resample(df.loc[df['class'].notnull()].reset_index(), df.loc[df['class'].notnull(),'class'])
# summarize the new class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0.0: 9974, 1.0: 9974, 2.0: 9974})

# %%
len(pd.unique(X['index']))
# Out:
# 19934

# %%
X.groupby('class').size()
# Out:
# class
# 0.0    9974
# 1.0    9974
# 2.0    9974
# dtype: int64

# %%
X.head()
# Out:
#     index         0         1         2         3         4         5  \
# 0  154175 -0.289675  0.394769  0.256888 -0.317372 -0.237715  0.167305
# 1  154177 -0.203194  0.273622  0.243855 -0.281782  0.095889  0.274552
# 2  154179 -0.112905  0.204361  0.368729 -0.302603 -0.023144  0.152470
# 3  154180 -0.165507  0.221519  0.352529 -0.249288 -0.080767  0.211572
# 4  154186 -0.225182  0.188634  0.405607 -0.091972 -0.033343  0.101976
#
#           6         7         8  ...       110       111       112       113  \
# 0 -0.198700  0.171249 -0.033327  ...  0.001391  0.840816  0.179573  0.485714
# 1 -0.137389  0.273008 -0.054578  ...  0.000026  0.697470  0.240055  0.495575
# 2 -0.110966  0.133138 -0.068070  ... -0.000165  0.652331  0.247898  0.494681
# 3 -0.242924  0.189266 -0.148492  ... -0.000314  0.691111  0.241398  0.491667
# 4 -0.136606  0.192652 -0.094230  ... -0.000344  0.713955  0.229247  0.495283
#
#         114  115       116       117       118  class
# 0  0.288557    1  1.000000  3.951378  0.000000    0.0
# 1  0.288664    1  1.000000  3.457491  0.000000    0.0
# 2  0.288659    1  1.000000  3.258881  0.000000    0.0
# 3  0.288635    2  0.983333  3.456722  0.016667    0.0
# 4  0.288662    3  0.981132  3.583734  0.018868    0.0
#
# [5 rows x 121 columns]

# %%
a = df.loc[df['class'].isnull()].reset_index()

# %%
overSampled = pd.concat([X,a]).set_index('index')

# %%
overSampled.head()
# Out:
#                0         1         2         3         4         5         6  \
# index
# 154175 -0.289675  0.394769  0.256888 -0.317372 -0.237715  0.167305 -0.198700
# 154177 -0.203194  0.273622  0.243855 -0.281782  0.095889  0.274552 -0.137389
# 154179 -0.112905  0.204361  0.368729 -0.302603 -0.023144  0.152470 -0.110966
# 154180 -0.165507  0.221519  0.352529 -0.249288 -0.080767  0.211572 -0.242924
# 154186 -0.225182  0.188634  0.405607 -0.091972 -0.033343  0.101976 -0.136606
#
#                7         8         9  ...       110       111       112  \
# index                                 ...
# 154175  0.171249 -0.033327 -0.001526  ...  0.001391  0.840816  0.179573
# 154177  0.273008 -0.054578  0.027165  ...  0.000026  0.697470  0.240055
# 154179  0.133138 -0.068070 -0.022307  ... -0.000165  0.652331  0.247898
# 154180  0.189266 -0.148492 -0.037466  ... -0.000314  0.691111  0.241398
# 154186  0.192652 -0.094230  0.021252  ... -0.000344  0.713955  0.229247
#
#              113       114  115       116       117       118  class
# index
# 154175  0.485714  0.288557    1  1.000000  3.951378  0.000000    0.0
# 154177  0.495575  0.288664    1  1.000000  3.457491  0.000000    0.0
# 154179  0.494681  0.288659    1  1.000000  3.258881  0.000000    0.0
# 154180  0.491667  0.288635    2  0.983333  3.456722  0.016667    0.0
# 154186  0.495283  0.288662    3  0.981132  3.583734  0.018868    0.0
#
# [5 rows x 120 columns]

# %% [markdown]
# ## Apply Missfores

# %%
# %%time

imputer = MissForest(random_state=42, class_weight='balanced')
imputed = imputer.fit_transform(overSampled, cat_vars=119)
imputed
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# CPU times: user 4min 43s, sys: 1.88 s, total: 4min 45s
# Wall time: 43.5 s
# array([[-0.28967483,  0.39476911,  0.25688809, ...,  3.95137796,
#          0.        ,  0.        ],
#        [-0.20319405,  0.27362184,  0.24385467, ...,  3.45749102,
#          0.        ,  0.        ],
#        [-0.11290469,  0.20436135,  0.36872937, ...,  3.25888057,
#          0.        ,  0.        ],
#        ...,
#        [-0.11628602,  0.29573326,  0.40448253, ...,  4.0708538 ,
#          0.        ,  1.        ],
#        [-0.09307639,  0.14522664,  0.37296448, ...,  3.90355169,
#          0.0060241 ,  1.        ],
#        [-0.18077336,  0.1715945 ,  0.29286598, ...,  2.947734  ,
#          0.00746269,  1.        ]])

# %%
cat_cols=['class']
imputed = pd.DataFrame(imputed, columns=overSampled.columns.tolist())

# %%
imputed.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.289675  0.394769  0.256888 -0.317372 -0.237715  0.167305 -0.198700
# 1 -0.203194  0.273622  0.243855 -0.281782  0.095889  0.274552 -0.137389
# 2 -0.112905  0.204361  0.368729 -0.302603 -0.023144  0.152470 -0.110966
# 3 -0.165507  0.221519  0.352529 -0.249288 -0.080767  0.211572 -0.242924
# 4 -0.225182  0.188634  0.405607 -0.091972 -0.033343  0.101976 -0.136606
#
#           7         8         9  ...       110       111       112       113  \
# 0  0.171249 -0.033327 -0.001526  ...  0.001391  0.840816  0.179573  0.485714
# 1  0.273008 -0.054578  0.027165  ...  0.000026  0.697470  0.240055  0.495575
# 2  0.133138 -0.068070 -0.022307  ... -0.000165  0.652331  0.247898  0.494681
# 3  0.189266 -0.148492 -0.037466  ... -0.000314  0.691111  0.241398  0.491667
# 4  0.192652 -0.094230  0.021252  ... -0.000344  0.713955  0.229247  0.495283
#
#         114  115       116       117       118  class
# 0  0.288557  1.0  1.000000  3.951378  0.000000    0.0
# 1  0.288664  1.0  1.000000  3.457491  0.000000    0.0
# 2  0.288659  1.0  1.000000  3.258881  0.000000    0.0
# 3  0.288635  2.0  0.983333  3.456722  0.016667    0.0
# 4  0.288662  3.0  0.981132  3.583734  0.018868    0.0
#
# [5 rows x 120 columns]

# %%
imputed.index = overSampled.index

# %%
imputed.head()
# Out:
#                0         1         2         3         4         5         6  \
# index
# 154175 -0.289675  0.394769  0.256888 -0.317372 -0.237715  0.167305 -0.198700
# 154177 -0.203194  0.273622  0.243855 -0.281782  0.095889  0.274552 -0.137389
# 154179 -0.112905  0.204361  0.368729 -0.302603 -0.023144  0.152470 -0.110966
# 154180 -0.165507  0.221519  0.352529 -0.249288 -0.080767  0.211572 -0.242924
# 154186 -0.225182  0.188634  0.405607 -0.091972 -0.033343  0.101976 -0.136606
#
#                7         8         9  ...       110       111       112  \
# index                                 ...
# 154175  0.171249 -0.033327 -0.001526  ...  0.001391  0.840816  0.179573
# 154177  0.273008 -0.054578  0.027165  ...  0.000026  0.697470  0.240055
# 154179  0.133138 -0.068070 -0.022307  ... -0.000165  0.652331  0.247898
# 154180  0.189266 -0.148492 -0.037466  ... -0.000314  0.691111  0.241398
# 154186  0.192652 -0.094230  0.021252  ... -0.000344  0.713955  0.229247
#
#              113       114  115       116       117       118  class
# index
# 154175  0.485714  0.288557  1.0  1.000000  3.951378  0.000000    0.0
# 154177  0.495575  0.288664  1.0  1.000000  3.457491  0.000000    0.0
# 154179  0.494681  0.288659  1.0  1.000000  3.258881  0.000000    0.0
# 154180  0.491667  0.288635  2.0  0.983333  3.456722  0.016667    0.0
# 154186  0.495283  0.288662  3.0  0.981132  3.583734  0.018868    0.0
#
# [5 rows x 120 columns]

# %%
imputed.groupby('class').size()
# Out:
# class
# 0.0     10274
# 1.0    158366
# 2.0     74112
# dtype: int64

# %%
metadata = pd.read_json('data_and_meta.json')
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 232748 entries, 0 to 284530
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   index           232748 non-null  int64
#  1   reviewerID      232748 non-null  object
#  2   asin            232748 non-null  object
#  3   reviewerName    230910 non-null  object
#  4   helpful         232748 non-null  object
#  5   reviewText      232748 non-null  object
#  6   overall         232748 non-null  int64
#  7   summary         232748 non-null  object
#  8   unixReviewTime  232748 non-null  int64
#  9   reviewTime      232748 non-null  object
#  10  features        232748 non-null  object
#  11  amazonCategory  232748 non-null  object
#  12  class           19918 non-null   object
#  13  title           106284 non-null  object
#  14  description     232748 non-null  object
#  15  feature         232748 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 30.2+ MB

# %%
imputed['CLASS'] = le.inverse_transform(imputed['class'].astype(int)[imputed['class'].notnull()])
imputed.groupby('CLASS').size()
# Out:
# CLASS
# Q1     10274
# Q2    158366
# Q4     74112
# dtype: int64

# %%
imputed
# Out:
#                0         1         2         3         4         5         6  \
# index
# 154175 -0.289675  0.394769  0.256888 -0.317372 -0.237715  0.167305 -0.198700
# 154177 -0.203194  0.273622  0.243855 -0.281782  0.095889  0.274552 -0.137389
# 154179 -0.112905  0.204361  0.368729 -0.302603 -0.023144  0.152470 -0.110966
# 154180 -0.165507  0.221519  0.352529 -0.249288 -0.080767  0.211572 -0.242924
# 154186 -0.225182  0.188634  0.405607 -0.091972 -0.033343  0.101976 -0.136606
# ...          ...       ...       ...       ...       ...       ...       ...
# 232743 -0.186514  0.099457  0.393527 -0.186841  0.037206  0.140150 -0.143451
# 232744 -0.212278  0.177555  0.390303 -0.246410 -0.130181  0.186109 -0.030990
# 232745 -0.116286  0.295733  0.404483 -0.161157 -0.175289  0.202572 -0.013252
# 232746 -0.093076  0.145227  0.372964 -0.218381 -0.008757  0.194206 -0.045708
# 232747 -0.180773  0.171595  0.292866 -0.165053  0.051154  0.117303 -0.056381
#
#                7         8         9  ...       111       112       113  \
# index                                 ...
# 154175  0.171249 -0.033327 -0.001526  ...  0.840816  0.179573  0.485714
# 154177  0.273008 -0.054578  0.027165  ...  0.697470  0.240055  0.495575
# 154179  0.133138 -0.068070 -0.022307  ...  0.652331  0.247898  0.494681
# 154180  0.189266 -0.148492 -0.037466  ...  0.691111  0.241398  0.491667
# 154186  0.192652 -0.094230  0.021252  ...  0.713955  0.229247  0.495283
# ...          ...       ...       ...  ...       ...       ...       ...
# 232743  0.161884 -0.102061  0.058485  ...  0.647394  0.252082  0.499289
# 232744  0.232672 -0.103300  0.034690  ...  0.784241  0.210243  0.491228
# 232745  0.300210  0.076071 -0.095648  ...  0.836601  0.142492  0.490196
# 232746  0.268212 -0.103843  0.044485  ...  0.789229  0.211758  0.496988
# 232747  0.132868 -0.036771  0.053600  ...  0.582758  0.270610  0.496269
#
#              114  115       116       117       118  class  CLASS
# index
# 154175  0.288557  1.0  1.000000  3.951378  0.000000    0.0     Q1
# 154177  0.288664  1.0  1.000000  3.457491  0.000000    0.0     Q1
# 154179  0.288659  1.0  1.000000  3.258881  0.000000    0.0     Q1
# 154180  0.288635  2.0  0.983333  3.456722  0.016667    0.0     Q1
# 154186  0.288662  3.0  0.981132  3.583734  0.018868    0.0     Q1
# ...          ...  ...       ...       ...       ...    ...    ...
# 232743  0.288675  2.0  0.998578  3.321696  0.001422    1.0     Q2
# 232744  0.288631  2.0  0.982456  3.925651  0.017544    1.0     Q2
# 232745  0.288620  1.0  1.000000  4.070854  0.000000    1.0     Q2
# 232746  0.288670  2.0  0.993976  3.903552  0.006024    1.0     Q2
# 232747  0.288667  2.0  0.992537  2.947734  0.007463    1.0     Q2
#
# [242752 rows x 121 columns]

# %%
len(pd.unique(imputed.index))
# Out:
# 232748

# %%
metadata.set_index('index')
# Out:
#                   reviewerID        asin                         reviewerName  \
# index
# 0             A1JUPR7LPMYG1X  B00009V2QX                 Chef Kim "My Review"
# 1              A6YT8ATZ4SEKT  B00009V2QX                             C. Moran
# 2       A0678500JUN3N7KUG4PS  B000056OWW                                GigiS
# 3              A4DRGD09QEE9I  B00009V2QX              C. R. Dyer "home maker"
# 4              ABT4HGNR22RWO  B00009V2QX                Daniel L. Kellett Sr.
# ...                      ...         ...                                  ...
# 232743         AGGAQLXPVGM5D  B002BDU7U2                         Eagle Vision
# 232744        A261FJIRA4ELFV  B002BDU7U2                    Endi "Endiablado"
# 232745         AR0XBJRF01FFK  B002BDU7U2                                ewang
# 232746        A1UE2O203AAMEJ  B002BDU7U2                             G. Jones
# 232747        A32O5FZH994CNY  B002BDU7U2  G. Ware Cornell Jr. "anotherlawyer"
#
#          helpful                                         reviewText  overall  \
# index
# 0         [0, 0]  Its time for me to purchase another box. great...        4
# 1         [0, 0]  Recieved OLD black and silver procell package,...        3
# 2         [0, 0]  The best cold sore remover product I've ever u...        5
# 3         [0, 0]  If you've ever noticed your flashlights are di...        5
# 4         [0, 0]  Received fast and as described.  I have only u...        5
# ...          ...                                                ...      ...
# 232743  [13, 14]  WHAT COMES IN THE BOXCaseMicro USB CableInstru...        4
# 232744    [2, 2]  No wonder the price was so low, this battery p...        1
# 232745    [2, 2]  I bought this almost 2 years ago honestly, and...        5
# 232746    [0, 2]  I bought this originally for the outrageous pr...        1
# 232747    [2, 3]  Good style is essential to any Apple design. I...        4
#
#                                              summary  unixReviewTime  \
# index
# 0                                              Great      1356739200
# 1                                 recieved OLD STOCK      1401840000
# 2                                     Great product.      1403049600
# 3                                          Batteries      1357516800
# 4                          Big bang for your buck...      1320105600
# ...                                              ...             ...
# 232743  Very good case and battery with a limitation      1250467200
# 232744                                       garbage      1301961600
# 232745                          Good backup charger!      1391990400
# 232746                                  Barely works      1283990400
# 232747                                       Two'fer      1253923200
#
#          reviewTime                                           features  \
# index
# 0       12 29, 2012  [-0.0987924889, 0.24677984890000002, 0.3721822...
# 1        06 4, 2014  [-0.07366212, 0.345128, 0.30181372, -0.4765604...
# 2       06 18, 2014  [-0.2395376471, 0.2173122941, 0.3914945765, -0...
# 3        01 7, 2013  [-0.2284705294, 0.2700145882, 0.45578470590000...
# 4        11 1, 2011  [-0.1749965652, 0.2965097391, 0.2584427783, -0...
# ...             ...                                                ...
# 232743  08 17, 2009  [-0.1865138805, 0.0994569393, 0.39352668090000...
# 232744   04 5, 2011  [-0.2122780702, 0.177555193, 0.390302733300000...
# 232745  02 10, 2014  [-0.1162860196, 0.2957332569, 0.4044825294, -0...
# 232746   09 9, 2010  [-0.0930763855, 0.1452266367, 0.37296447860000...
# 232747  09 26, 2009  [-0.1807733582, 0.171594503, 0.2928659769, -0....
#
#        amazonCategory class  \
# index
# 0              health  None
# 1              health  None
# 2              health  None
# 3              health  None
# 4              health  None
# ...               ...   ...
# 232743         mobile  None
# 232744         mobile  None
# 232745         mobile  None
# 232746         mobile  None
# 232747         mobile  None
#
#                                                     title  \
# index
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 232743  Mophie Juice Pack Air Case and Rechargeable Ba...
# 232744  Mophie Juice Pack Air Case and Rechargeable Ba...
# 232745  Mophie Juice Pack Air Case and Rechargeable Ba...
# 232746  Mophie Juice Pack Air Case and Rechargeable Ba...
# 232747  Mophie Juice Pack Air Case and Rechargeable Ba...
#
#                                               description  \
# index
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 232743  The Juice Pack Air is a rechargeable external ...
# 232744  The Juice Pack Air is a rechargeable external ...
# 232745  The Juice Pack Air is a rechargeable external ...
# 232746  The Juice Pack Air is a rechargeable external ...
# 232747  The Juice Pack Air is a rechargeable external ...
#
#                                                   feature
# index
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 232743  iPhone case and battery pack protects and adds...
# 232744  iPhone case and battery pack protects and adds...
# 232745  iPhone case and battery pack protects and adds...
# 232746  iPhone case and battery pack protects and adds...
# 232747  iPhone case and battery pack protects and adds...
#
# [232748 rows x 15 columns]

# %%
All = pd.merge(imputed,metadata, how='outer', on='index')

# %%
All.info(max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242752 entries, 0 to 242751
# Data columns (total 137 columns):
#  #    Column          Non-Null Count   Dtype
# ---   ------          --------------   -----
#  0    index           242752 non-null  int64
#  1    0               242752 non-null  float64
#  2    1               242752 non-null  float64
#  3    2               242752 non-null  float64
#  4    3               242752 non-null  float64
#  5    4               242752 non-null  float64
#  6    5               242752 non-null  float64
#  7    6               242752 non-null  float64
#  8    7               242752 non-null  float64
#  9    8               242752 non-null  float64
#  10   9               242752 non-null  float64
#  11   10              242752 non-null  float64
#  12   11              242752 non-null  float64
#  13   12              242752 non-null  float64
#  14   13              242752 non-null  float64
#  15   14              242752 non-null  float64
#  16   15              242752 non-null  float64
#  17   16              242752 non-null  float64
#  18   17              242752 non-null  float64
#  19   18              242752 non-null  float64
#  20   19              242752 non-null  float64
#  21   20              242752 non-null  float64
#  22   21              242752 non-null  float64
#  23   22              242752 non-null  float64
#  24   23              242752 non-null  float64
#  25   24              242752 non-null  float64
#  26   25              242752 non-null  float64
#  27   26              242752 non-null  float64
#  28   27              242752 non-null  float64
#  29   28              242752 non-null  float64
#  30   29              242752 non-null  float64
#  31   30              242752 non-null  float64
#  32   31              242752 non-null  float64
#  33   32              242752 non-null  float64
#  34   33              242752 non-null  float64
#  35   34              242752 non-null  float64
#  36   35              242752 non-null  float64
#  37   36              242752 non-null  float64
#  38   37              242752 non-null  float64
#  39   38              242752 non-null  float64
#  40   39              242752 non-null  float64
#  41   40              242752 non-null  float64
#  42   41              242752 non-null  float64
#  43   42              242752 non-null  float64
#  44   43              242752 non-null  float64
#  45   44              242752 non-null  float64
#  46   45              242752 non-null  float64
#  47   46              242752 non-null  float64
#  48   47              242752 non-null  float64
#  49   48              242752 non-null  float64
#  50   49              242752 non-null  float64
#  51   50              242752 non-null  float64
#  52   51              242752 non-null  float64
#  53   52              242752 non-null  float64
#  54   53              242752 non-null  float64
#  55   54              242752 non-null  float64
#  56   55              242752 non-null  float64
#  57   56              242752 non-null  float64
#  58   57              242752 non-null  float64
#  59   58              242752 non-null  float64
#  60   59              242752 non-null  float64
#  61   60              242752 non-null  float64
#  62   61              242752 non-null  float64
#  63   62              242752 non-null  float64
#  64   63              242752 non-null  float64
#  65   64              242752 non-null  float64
#  66   65              242752 non-null  float64
#  67   66              242752 non-null  float64
#  68   67              242752 non-null  float64
#  69   68              242752 non-null  float64
#  70   69              242752 non-null  float64
#  71   70              242752 non-null  float64
#  72   71              242752 non-null  float64
#  73   72              242752 non-null  float64
#  74   73              242752 non-null  float64
#  75   74              242752 non-null  float64
#  76   75              242752 non-null  float64
#  77   76              242752 non-null  float64
#  78   77              242752 non-null  float64
#  79   78              242752 non-null  float64
#  80   79              242752 non-null  float64
#  81   80              242752 non-null  float64
#  82   81              242752 non-null  float64
#  83   82              242752 non-null  float64
#  84   83              242752 non-null  float64
#  85   84              242752 non-null  float64
#  86   85              242752 non-null  float64
#  87   86              242752 non-null  float64
#  88   87              242752 non-null  float64
#  89   88              242752 non-null  float64
#  90   89              242752 non-null  float64
#  91   90              242752 non-null  float64
#  92   91              242752 non-null  float64
#  93   92              242752 non-null  float64
#  94   93              242752 non-null  float64
#  95   94              242752 non-null  float64
#  96   95              242752 non-null  float64
#  97   96              242752 non-null  float64
#  98   97              242752 non-null  float64
#  99   98              242752 non-null  float64
#  100  99              242752 non-null  float64
#  101  100             242752 non-null  float64
#  102  101             242752 non-null  float64
#  103  102             242752 non-null  float64
#  104  103             242752 non-null  float64
#  105  104             242752 non-null  float64
#  106  105             242752 non-null  float64
#  107  106             242752 non-null  float64
#  108  107             242752 non-null  float64
#  109  108             242752 non-null  float64
#  110  109             242752 non-null  float64
#  111  110             242752 non-null  float64
#  112  111             242752 non-null  float64
#  113  112             242752 non-null  float64
#  114  113             242752 non-null  float64
#  115  114             242752 non-null  float64
#  116  115             242752 non-null  float64
#  117  116             242752 non-null  float64
#  118  117             242752 non-null  float64
#  119  118             242752 non-null  float64
#  120  class_x         242752 non-null  float64
#  121  CLASS           242752 non-null  object
#  122  reviewerID      242752 non-null  object
#  123  asin            242752 non-null  object
#  124  reviewerName    240914 non-null  object
#  125  helpful         242752 non-null  object
#  126  reviewText      242752 non-null  object
#  127  overall         242752 non-null  int64
#  128  summary         242752 non-null  object
#  129  unixReviewTime  242752 non-null  int64
#  130  reviewTime      242752 non-null  object
#  131  features        242752 non-null  object
#  132  amazonCategory  242752 non-null  object
#  133  class_y         29131 non-null   object
#  134  title           116079 non-null  object
#  135  description     242752 non-null  object
#  136  feature         242752 non-null  object
# dtypes: float64(120), int64(3), object(14)
# memory usage: 255.6+ MB

# %%
col = [ column for column in All.columns if column not in ['class_y','class_x','reviewerName','features']]
All = All[col]

# %%
All.iloc[200000,-13:].values
# Out:
# array(['Q2', 'AE55ZYNOXOERC', 'B00003006E', list([3, 7]),
#        'I had no idea what this is/was,, but I bought it.  It works!Good price, excellent service(delivery).',
#        4, 'Computer "box"', 1192579200, '10 17, 2007', 'electronics',
#        'Cisco-Linksys EZXS55W EtherFast 10/100 5-Port Workgroup Switch',
#        "5 PORT ETHERFAST DESKTOP SWITCH The EtherFast 10/100 5-Port Switch provides an easy and flexible way to boost your network's performance while migrating to the power of Fast Ethernet. It is designed to meet the needs of small businesses, medium-size businesses, and small-office/home-office networks, and it allows you to run high-end video, multimedia, and other speed-intensive applications at blistering speeds. With support for half- and full-duplex speeds, the switches allow your network to run at 10 Mbps, 20 Mbps, 100 Mbps, and an incredible 200 Mbps, which provides a cost-effective solution if you ever decide to upgrade your Ethernet network. The EtherFast 10/100 5-Port Switch eliminates data bottlenecks and bandwidth constraints, optimizing network performance while protecting your investment in your existing infrastructure. By migrating your entire network to 100 Mbps Fast Ethernet with the EtherFast 10/100 5-Port Switch, you will have the power to double your network's performance with dedicated, full-duplex bandwidth on every port.",
#        '10/100 dual-speed per-port auto sensing Perfect for optimizing 10-BaseT and 100-BaseTX hardware on the same network Uplink port for easy expansion and maximum scalability Reach speeds of up to 200 Mbps in full-duplex operation Eliminate bandwidth constraints and clear up bottlenecks'],
#       dtype=object)

# %%
All.iloc[230000,-13:].values
# Out:
# array(['Q2', 'A2CTNSIVANWUIH', '0006511252', list([0, 2]),
#        "I've been enjoying the Flashman series from my local library, and was looking forwards to the Kindle edition. But 12.99 is just too expensive to make it worthwhile. I'd pay 5.99, but not more. Also, has Kindle figured out how to implement the Notes feature such that it's easy to use? For the print books the notes are key to connecting the fiction and the fact, and you have to be able to easily jump back and forth. Earlier Kindle books weren't too good at this, and I hope that this has been addressed in this series.",
#        2, 'A great series, but Kindle price too high', 1365724800,
#        '04 12, 2013', 'books', 'The Flashman (The Flashman Papers)',
#        "The first instalment of the Flashman Papers sees the fag-roasting rotter from Tom Brown's Schooldays commence his military career as a reluctant secret agent in Afghanistan. Expelled from Rugby for drunkenness, and none too welcome at home after seducing his father's mistress, the young Flashman embarks on a military career with Lord Cardigan's Hussars. En route to Afghanistan, our hero hones his skills as a soldier, duellist, imposter, coward and amorist (mastering all 97 ways of Hindu love-making during a brief sojourn in Calcutta), before being pressed into reluctant service as a secret agent. His Afghan adventures culminate in a starring role in that great historic disaster, the Retreat from Kabul.",
#        ''], dtype=object)

# %%
categorical = ['CLASS']  
le = preprocessing.LabelEncoder()
All['target'] = le.fit_transform(All['CLASS'])

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.manifold import Isomap, TSNE, MDS, LocallyLinearEmbedding
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.naive_bayes import MultinomialNB

# %%
All.groupby('target').size()
# Out:
# target
# 0     10274
# 1    158366
# 2     74112
# dtype: int64

# %% [markdown]
# ## Applying TF-IDF:

# %%
# %%time

X_ = All['reviewText']
y_ = All['target']

pipe = Pipeline([('vectorizer', CountVectorizer()),  
                 ('tfidf', TfidfTransformer()), 
                 ('classifier', RandomForestClassifier(n_jobs=5, max_depth=13))])
X_train, X_test, y_train, y_test = train_test_split(X_, y_, test_size=0.33, random_state=42)

classifier = pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.03      0.05      3321
#            1       0.70      1.00      0.82     52389
#            2       0.99      0.22      0.36     24399
#
#     accuracy                           0.72     80109
#    macro avg       0.90      0.42      0.41     80109
# weighted avg       0.80      0.72      0.65     80109
#
# CPU times: user 1min, sys: 398 ms, total: 1min 1s
# Wall time: 26.8 s

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[   91,  3230,     0],
#        [    0, 52356,    33],
#        [    0, 19059,  5340]])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix

class_names= ['Q1','Q2', 'Q4']
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(classifier, X_test, y_test,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Confusion matrix, without normalization
# [[   91  3230     0]
#  [    0 52356    33]
#  [    0 19059  5340]]
# Normalized confusion matrix
# [[2.74013851e-02 9.72598615e-01 0.00000000e+00]
#  [0.00000000e+00 9.99370097e-01 6.29903224e-04]
#  [0.00000000e+00 7.81138571e-01 2.18861429e-01]]

# %% [markdown]
# ## Applying features:

# %%
from sklearn.ensemble import AdaBoostClassifier

X_ =  All.iloc[:,1:120]
y_ = All['target']

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', AdaBoostClassifier(n_estimators=100))])

X_train, X_test, y_train, y_test = train_test_split(X_, y_, test_size=0.33, random_state=42)


classifier = pipe.fit(X_train, y_train)

# %%
y_pred = pipe.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.78      3321
#            1       0.97      0.86      0.91     52389
#            2       0.78      0.97      0.86     24399
#
#     accuracy                           0.89     80109
#    macro avg       0.84      0.87      0.85     80109
# weighted avg       0.90      0.89      0.89     80109

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix

class_names= ['Q1','Q2', 'Q4']
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(classifier, X_test, y_test,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 2560   760     1]
#  [  719 44950  6720]
#  [    0   783 23616]]
# Normalized confusion matrix
# [[7.70852153e-01 2.28846733e-01 3.01114122e-04]
#  [1.37242551e-02 8.58004543e-01 1.28271202e-01]
#  [0.00000000e+00 3.20914792e-02 9.67908521e-01]]
